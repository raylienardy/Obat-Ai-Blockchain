# %%
import os
import csv
import pandas as pd
from ultralytics import YOLO
# Pastikan working directory adalah root proyek (naik satu level dari folder notebooks)
if os.getcwd().endswith('notebooks'):
    os.chdir('..')
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: e:\AIC\BlockchainAI

# %%
demo_dir = 'data/demo_test'
files = sorted([f for f in os.listdir(demo_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
print(f"Total file gambar: {len(files)}\n")
for f in files:
    print(f)

# %%
# Daftar ground truth (sudah disediakan oleh Owner)
data = [
    # ========== obat (mengandung "asli"/"palsu") ==========
    ("ASLI (1).jpeg", "obat"),
    ("ASLI (2).jpeg", "obat"),
    ("ASLI (3).jpeg", "obat"),
    ("ASLI (4).jpeg", "obat"),
    ("ASLI (5).jpeg", "obat"),
    ("ASLI1 (1).jpeg", "obat"),
    ("ASLI1.jpeg", "obat"),
    ("ASLI2 (1).jpeg", "obat"),
    ("ASLI2.jpeg", "obat"),
    ("ASLI3 (1).jpeg", "obat"),
    ("ASLI3.jpeg", "obat"),
    ("ASLI4 (1).jpeg", "obat"),
    ("ASLI4.jpeg", "obat"),
    ("ASLI5 (1).jpeg", "obat"),
    ("ASLI5.jpeg", "obat"),
    ("ASLIII (1).jpeg", "obat"),
    ("ASLIII (2).jpeg", "obat"),
    ("ASLIII (3).jpeg", "obat"),
    ("ASLIII (4).jpeg", "obat"),
    ("ASLIII (5).jpeg", "obat"),
    ("PALSU (1).jpeg", "obat"),
    ("PALSU (2).jpeg", "obat"),
    ("PALSU (3).jpeg", "obat"),
    ("PALSU (4).jpeg", "obat"),
    ("PALSU (5).jpeg", "obat"),
    ("PALSU1.jpeg", "obat"),
    ("PALSU2.jpeg", "obat"),
    ("PALSU3 (1).jpeg", "obat"),
    ("PALSU3.jpeg", "obat"),
    ("PALSU4.jpeg", "obat"),
    ("PALSU5.jpeg", "obat"),
    ("PALSUUU (1).jpeg", "obat"),
    ("PALSUUU (2).jpeg", "obat"),
    ("PALSUUU (3).jpeg", "obat"),
    ("PALSUUU (4).jpeg", "obat"),
    ("PALSUUU (5).jpeg", "obat"),
    ("asli (1).jpeg", "obat"),
    ("asli (1).jpg", "obat"),
    ("asli (10).jpg", "obat"),
    ("asli (2).jpeg", "obat"),
    ("asli (2).jpg", "obat"),
    ("asli (3).jpeg", "obat"),
    ("asli (3).jpg", "obat"),
    ("asli (4).jpeg", "obat"),
    ("asli (4).jpg", "obat"),
    ("asli (5).jpeg", "obat"),
    ("asli (5).jpg", "obat"),
    ("asli (6).jpg", "obat"),
    ("asli (7).jpg", "obat"),
    ("asli (8).jpg", "obat"),
    ("asli (9).jpg", "obat"),
    ("asli01 (1).jpeg", "obat"),
    ("asli01 (2).jpeg", "obat"),
    ("asli01 (3).jpeg", "obat"),
    ("asli01 (4).jpeg", "obat"),
    ("asli01.jpeg", "obat"),
    ("asli02 (1).jpeg", "obat"),
    ("asli02 (2).jpeg", "obat"),
    ("asli02 (3).jpeg", "obat"),
    ("asli02 (4).jpeg", "obat"),
    ("asli02.jpeg", "obat"),
    ("asli03 (1).jpeg", "obat"),
    ("asli03 (2).jpeg", "obat"),
    ("asli03 (3).jpeg", "obat"),
    ("asli03 (4).jpeg", "obat"),
    ("asli03.jpeg", "obat"),
    ("asli04 (1).jpeg", "obat"),
    ("asli04 (2).jpeg", "obat"),
    ("asli04 (3).jpeg", "obat"),
    ("asli04 (4).jpeg", "obat"),
    ("asli04.jpeg", "obat"),
    ("asli05 (1).jpeg", "obat"),
    ("asli05 (2).jpeg", "obat"),
    ("asli05 (3).jpeg", "obat"),
    ("asli05 (4).jpeg", "obat"),
    ("asli05.jpeg", "obat"),
    ("asli06 (1).jpeg", "obat"),
    ("asli06.jpeg", "obat"),
    ("asli1 (1).jpeg", "obat"),
    ("asli1 (2).jpeg", "obat"),
    ("asli1.jpeg", "obat"),
    ("asli10.jpeg", "obat"),
    ("asli11.jpeg", "obat"),
    ("asli12.jpeg", "obat"),
    ("asli13.jpeg", "obat"),
    ("asli14.jpeg", "obat"),
    ("asli15.jpeg", "obat"),
    ("asli16.jpeg", "obat"),
    ("asli17.jpeg", "obat"),
    ("asli2 (1).jpeg", "obat"),
    ("asli2 (2).jpeg", "obat"),
    ("asli2.jpeg", "obat"),
    ("asli3 (1).jpeg", "obat"),
    ("asli3.jpeg", "obat"),
    ("asli4 (1).jpeg", "obat"),
    ("asli4.jpeg", "obat"),
    ("asli5 (1).jpeg", "obat"),
    ("asli5 (2).jpeg", "obat"),
    ("asli5.jpeg", "obat"),
    ("asli6.jpeg", "obat"),
    ("asli7.jpeg", "obat"),
    ("asli8.jpeg", "obat"),
    ("asli9.jpeg", "obat"),
    ("asli_(1).jpg", "obat"),
    ("asli_(10).jpg", "obat"),
    ("asli_(2).jpg", "obat"),
    ("asli_(3).jpg", "obat"),
    ("asli_(4).jpg", "obat"),
    ("asli_(5).jpg", "obat"),
    ("asli_(6).jpg", "obat"),
    ("asli_(7).jpg", "obat"),
    ("asli_(8).jpg", "obat"),
    ("asli_(9).jpg", "obat"),
    ("asliiiiii01.jpeg", "obat"),
    ("asliiiiii02.jpeg", "obat"),
    ("asliiiiii03.jpeg", "obat"),
    ("asliiiiii04.jpeg", "obat"),
    ("asliiiiii05.jpeg", "obat"),
    ("asliiiiii06.jpeg", "obat"),
    ("palsu (1).jpeg", "obat"),
    ("palsu (1).jpg", "obat"),
    ("palsu (10).jpg", "obat"),
    ("palsu (2).jpeg", "obat"),
    ("palsu (2).jpg", "obat"),
    ("palsu (3).jpeg", "obat"),
    ("palsu (3).jpg", "obat"),
    ("palsu (4).jpeg", "obat"),
    ("palsu (4).jpg", "obat"),
    ("palsu (5).jpeg", "obat"),
    ("palsu (5).jpg", "obat"),
    ("palsu (6).jpg", "obat"),
    ("palsu (7).jpg", "obat"),
    ("Screenshot 2026-06-05 210453.png", "non_obat"),
    ("Screenshot 2026-06-07 143453.png", "non_obat"),
    ("Screenshot 2026-06-07 144253.png", "non_obat"),
    ("Screenshot 2026-06-09 145557.png", "non_obat"),
    ("Screenshot 2026-06-10 233857 (1).png", "non_obat"),
    ("Screenshot 2026-06-10 233857.png", "non_obat"),
    ("Screenshot 2026-06-10 234856.png", "non_obat"),
    ("Screenshot 2026-06-18 204244 (1).png", "non_obat"),
    ("Screenshot 2026-06-18 204244.png", "non_obat"),
    ("Screenshot 2026-06-18 204247.png", "non_obat"),
    ("Screenshot 2026-06-23 112915.png", "non_obat"),
    ("Screenshot 2026-06-23 150655 (1).png", "non_obat"),
    ("Screenshot 2026-06-23 150655.png", "non_obat"),
    ("c1aca82d-af01-4898-90df-9ac15bb137cd.jpg", "non_obat"),
    ("c3926483-d87c-4c63-9be5-7d5503e580f7.jpg", "non_obat"),
    ("pallsssuuuu01.jpeg", "non_obat"),
    ("pallsssuuuu02.jpeg", "non_obat"),
    ("pallsssuuuu03.jpeg", "non_obat"),
    ("pallsssuuuu04.jpeg", "non_obat"),
]
import os

demo_dir = 'data/demo_test'
all_files = [f for f in os.listdir(demo_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]

data = []
for fname in all_files:
    lower = fname.lower()
    if 'asli' in lower or 'palsu' in lower:
        category = 'obat'
    else:
        category = 'non_obat'
    data.append((fname, category))

import csv
csv_path = 'output/demo_test_ground_truth.csv'
with open(csv_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['filename', 'category'])
    writer.writerows(data)

print(f"✅ CSV dibuat dengan {len(data)} baris (berdasarkan isi folder)")
# Out:
# ✅ CSV dibuat dengan 215 baris (berdasarkan isi folder)

# %%
# Evaluasi
gt_path = 'output/demo_test_ground_truth.csv'
demo_dir = 'data/demo_test'
model_path = 'models/detector_model.pt'

gt = pd.read_csv(gt_path)
gt_clean = gt[gt['category'].isin(['obat', 'non_obat'])]
obat_files = gt_clean[gt_clean['category'] == 'obat']['filename'].tolist()
non_obat_files = gt_clean[gt_clean['category'] == 'non_obat']['filename'].tolist()

print(f"Jumlah gambar obat: {len(obat_files)}")
print(f"Jumlah gambar non-obat: {len(non_obat_files)}")

model = YOLO(model_path)
print("Model detektor dimuat.")

detected_obat = 0
failed_obat = []
for fname in obat_files:
    path = os.path.join(demo_dir, fname)
    results = model(path, conf=0.5, verbose=False)
    if len(results[0].boxes) > 0:
        detected_obat += 1
    else:
        failed_obat.append(fname)

false_pos = 0
false_pos_files = []
for fname in non_obat_files:
    path = os.path.join(demo_dir, fname)
    results = model(path, conf=0.5, verbose=False)
    if len(results[0].boxes) > 0:
        false_pos += 1
        false_pos_files.append(fname)

recall = detected_obat / len(obat_files) if len(obat_files) > 0 else 0
fp_rate = false_pos / len(non_obat_files) if len(non_obat_files) > 0 else 0

print("\n========== EVALUASI DETEKTOR (Phase 2B) ==========")
print(f"Recall (obat terdeteksi): {recall:.2%} ({detected_obat}/{len(obat_files)})")
print(f"False Positive (non‑obat terdeteksi): {false_pos} dari {len(non_obat_files)} ({fp_rate:.2%})")
if failed_obat:
    print(f"\nObat yang tidak terdeteksi ({len(failed_obat)}):")
    for f in failed_obat:
        print(f"  - {f}")
if false_pos_files:
    print(f"\nNon‑obat yang salah terdeteksi ({len(false_pos_files)}):")
    for f in false_pos_files:
        print(f"  - {f}")
print("====================================================")
# Out:
# Jumlah gambar obat: 191
# Jumlah gambar non-obat: 24
# Model detektor dimuat.
#
# ========== EVALUASI DETEKTOR (Phase 2B) ==========
# Recall (obat terdeteksi): 1.57% (3/191)
# False Positive (non‑obat terdeteksi): 0 dari 24 (0.00%)
#
# Obat yang tidak terdeteksi (188):
#   - asli (1)(1).jpeg
#   - ASLI (1).jpeg
#   - asli (1).jpg
#   - asli (10).jpg
#   - asli (2)(1).jpeg
#   - ASLI (2).jpeg
#   - asli (2).jpg
#   - asli (3)(1).jpeg
#   - ASLI (3).jpeg
#   - asli (3).jpg
#   - asli (4)(1).jpeg
#   - ASLI (4).jpeg
#   - asli (4).jpg
#   - asli (5)(1).jpeg
#   - ASLI (5).jpeg
#   - asli (5).jpg
#   - asli (6).jpg
#   - asli (7).jpg
#   - asli (8).jpg
#   - asli (9).jpg
#   - asli01(1).jpeg
#   - asli01(2).jpeg
#   - asli01(3).jpeg
#   - asli01(4).jpeg
#   - asli01.jpeg
#   - asli02(1).jpeg
#   - asli02(2).jpeg
#   - asli02(3).jpeg
#   - asli02(4).jpeg
#   - asli02.jpeg
#   - asli03(1).jpeg
#   - asli03(2).jpeg
#   - asli03(3).jpeg
#   - asli03(4).jpeg
#   - asli03.jpeg
# ...

# %%
# ============================================================
# Kalibrasi Threshold (Langkah 1)
# ============================================================
thresholds = [round(x * 0.05, 2) for x in range(2, 11)]  # 0.10 - 0.50

print("\n========== KALIBRASI THRESHOLD ==========")
print(f"{'Threshold':<10} {'Recall':<10} {'False Positive'}")
print("-" * 40)

for th in thresholds:
    detected_obat = 0
    false_pos = 0
    for fname in obat_files:
        path = os.path.join(demo_dir, fname)
        results = model(path, conf=th, verbose=False)
        if len(results[0].boxes) > 0:
            detected_obat += 1
    for fname in non_obat_files:
        path = os.path.join(demo_dir, fname)
        results = model(path, conf=th, verbose=False)
        if len(results[0].boxes) > 0:
            false_pos += 1
    recall = detected_obat / len(obat_files) if obat_files else 0
    print(f"{th:<10.2f} {recall:<10.2%} {false_pos}")
# Out:
# ========== KALIBRASI THRESHOLD ==========
# Threshold  Recall     False Positive
# ----------------------------------------
# 0.10       5.24%      0
# 0.15       4.19%      0
# 0.20       4.19%      0
# 0.25       3.66%      0
# 0.30       3.66%      0
# 0.35       2.09%      0
# 0.40       2.09%      0
# 0.45       2.09%      0
# 0.50       1.57%      0
